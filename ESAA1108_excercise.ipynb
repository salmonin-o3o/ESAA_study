# %% [markdown]
# <a href="https://colab.research.google.com/github/salmonin-o3o/ESAA_study/blob/main/ESAA1108_excercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. 단순 선형 회귀 분석**
# - 전복의 나이를 예측하는 선형회귀모델을 생성하세요.
# - 전복의 ‘성별’, ‘키’, ‘지름’, ‘높이’, ‘전체무게’, ‘몸통무게’, ‘내장무게’, ‘껍질무게’를 이용해 ‘껍질의 고리 수’를 예측한 뒤, **예측된 ‘껍질의 고리 수’에 1.5를 더하면 전복의 나이**가 됩니다.

# %%
# 기본 모듈 불러오기
import numpy as np
import pandas as pd

# %% [markdown]
# **1) 데이터 load 및 변형**

# %%
# 데이터 로드
from google.colab import drive
drive.mount('/content/drive')
data = pd.read_csv('/content/drive/My Drive/pythonprogramming/ESAA/abalone.csv')
data.head()
# Out:
# Mounted at /content/drive
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
print(data.shape)
# Out:
# (4177, 9)

# %%
# 성별 M은 Male, F는 Female, I는 Infant 이므로 따로 열 만들기
for label in "MFI":
    data[label] = data["Sex"] == label
data.drop('Sex', axis=1, inplace=True)

# %%
data.head()
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings      M      F      I
# 0         0.150     15   True  False  False
# 1         0.070      7   True  False  False
# 2         0.210      9  False   True  False
# 3         0.155     10   True  False  False
# 4         0.055      7  False  False   True

# %% [markdown]
# **2) X, y 선택**
# : y는 Rings열, X는 Rings열을 제외한 나머지를 선택하되 전부 실수가 되도록 한다.

# %%
# X,y 데이터 선택

y = data['Rings']
X = data.drop('Rings', axis=1).astype(float)

# %% [markdown]
#  **3) train/test set 분리**

# %%
# 필요한 모듈 불러오기
from sklearn.model_selection import train_test_split

# %%
# train과 test set 분리 (train:test = 7:3 비율로)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# **4) 선형회귀모델 생성, 모델 예측치 구하기**

# %%
#필요한 모듈 불러오기
from sklearn.linear_model import LinearRegression

# %%
#선형회귀모델 생성 및 훈련
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 모델 예측치 구하기
# 모델 예측치를 활용해 최종적으로 전복의 나이를 예측
y_preds = lr.predict(X_test)
y_preds * 1.5
# Out:
# array([19.8046875, 13.7578125, 15.46875  , ..., 13.875    , 28.1484375,
#        16.5234375])

# %% [markdown]
# **5) 모델 평가: MSE, RMSE, R2 score, corr 구하기**

# %%
#필요한 모듈 불러오기
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# - MSE, RMSE

# %%
#mse, rmse
mse = mean_squared_error(y_test, y_preds)
rmse = np.sqrt(mse)
print('MSE : {0:.3f}, RMSE : {1:.3f}'.format(mse, rmse))
# Out:
# MSE : 5.005, RMSE : 2.237

# %% [markdown]
# - R2 score

# %%
#R2 score 측정
print('Variance score : {0:.3f}'.format(r2_score(y_test, y_preds)))
# Out:
# Variance score : 0.525

# %% [markdown]
# - 회귀 절편값

# %%
#회귀 절편 값
print('절편 값:', lr.intercept_)
# Out:
# 절편 값: -75665726805056.67

# %% [markdown]
# - 회귀 계수 값

# %%
#회귀 계수 값
print('회귀 계수 값:', np.round(lr.coef_, 1))
# Out:
# 회귀 계수 값: [-2.00000000e-01  1.15000000e+01  7.10000000e+00  9.00000000e+00
#  -2.00000000e+01 -1.07000000e+01  9.70000000e+00  7.56657268e+13
#   7.56657268e+13  7.56657268e+13]

# %% [markdown]
# - 상관계수
#
# Hint: corr 함수 이용.

# %%
# 상관계수 구하기
data.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
# M               0.236543  0.240376  0.215459      0.252038        0.251793
# F               0.309666  0.318626  0.298421      0.299741        0.263991
# I              -0.551465 -0.564315 -0.518552     -0.557592       -0.521842
#
#                 Viscera weight  Shell weight     Rings         M         F  \
# Length                0.903018      0.897706  0.556720  0.236543  0.309666
# Diameter              0.899724      0.905330  0.574660  0.240376  0.318626
# Height                0.798319      0.817338  0.557467  0.215459  0.298421
# Whole weight          0.966375      0.955355  0.540390  0.252038  0.299741
# Shucked weight        0.931961      0.882617  0.420884  0.251793  0.263991
# Viscera weight        1.000000      0.907656  0.503819  0.242194  0.308444
# Shell weight          0.907656      1.000000  0.627574  0.235391  0.306319
# Rings                 0.503819      0.627574  1.000000  0.181831  0.250279
# M                     0.242194      0.235391  0.181831  1.000000 -0.512528
# F                     0.308444      0.306319  0.250279 -0.512528  1.000000
# I                    -0.556081     -0.546953 -0.436063 -0.522541 -0.464298
#
#                        I
# Length         -0.551465
# Diameter       -0.564315
# Height         -0.518552
# Whole weight   -0.557592
# Shucked weight -0.521842
# Viscera weight -0.556081
# Shell weight   -0.546953
# Rings          -0.436063
# M              -0.522541
# F              -0.464298
# I               1.000000

# %% [markdown]
# # **2. Polynomial features**

# %%
# PolynomialFeatures 라이브러리 호출
from sklearn.preprocessing import PolynomialFeatures

# %%
# 임의 데이터 생성

X = np.arange(6).reshape(3, 2)

df =  pd.DataFrame(X)
df.columns = ['x_1','x_2']
df
# Out:
#    x_1  x_2
# 0    0    1
# 1    2    3
# 2    4    5

# %%
# 차원은 2로 설정
# fit_transform 메소드를 통해 데이터 변환
# PolynomialFeatures로 변환 된 데이터를 데이터 프레임 형태로 변환
poly = PolynomialFeatures(degree=2)
poly.fit(X)
df_poly = poly.transform(X)
print('변환된 2차 다항식 계수 feature:\n', df_poly)
# Out:
# 변환된 2차 다항식 계수 feature:
#  [[ 1.  0.  1.  0.  0.  1.]
#  [ 1.  2.  3.  4.  6.  9.]
#  [ 1.  4.  5. 16. 20. 25.]]

# %%
# df_poly의 컬럼을 1,x1,x2,x1^2,x1*x2,x2^2 로 변경
df_poly =  pd.DataFrame(df_poly)
df_poly.columns = ['1', 'x1', 'x2', 'x1^2', 'x1*x2', 'x2^2']
df_poly
# Out:
#      1   x1   x2  x1^2  x1*x2  x2^2
# 0  1.0  0.0  1.0   0.0    0.0   1.0
# 1  1.0  2.0  3.0   4.0    6.0   9.0
# 2  1.0  4.0  5.0  16.0   20.0  25.0
